# %% [markdown]
# # Web Scraping with Pandas
#
# Pandas data analysis has basic web scraping capabilities. It can be used to extract data from websites and convert it into a pandas dataframe. In this notebook, I will show you how to scrape data from a website using pandas.
#
# The requirement to use pandas for web scraping is that the data is in tabular form. If the data is not in tabular form, you can use BeautifulSoup or Scrapy to scrape the data - Beautiful Soup will be covered in a separate notebook.

# %%
# good idea to start with date and python version
from datetime import datetime
print(f"Date: {datetime.now()}")
import sys
print(f"Python version: {sys.version}")

import pandas as pd # sometimes called excel on steroids
print(f"pandas version: {pd.__version__}")
# Out:
# Date: 2024-11-29 18:37:20.557853
# Python version: 3.12.5 (tags/v3.12.5:ff3bc82, Aug  6 2024, 20:45:27) [MSC v.1940 64 bit (AMD64)]
# pandas version: 2.2.2

# %%
# url = "https://www.ss.com/lv/real-estate/flats/riga/centre/sell/" 
# url = "https://www.ss.com/en/real-estate/flats/riga/centre/sell/"
# url = "https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/" # hand_over meaning renting
url = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/"
# notice how we can specify some parameters in the url
print(f"URL: {url}")
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/

# %%
# pandas can do some web scraping as long as there are tables
dfs = pd.read_html(url, header=0) # i know that i want the first row to server for column names
print(f"We got {len(dfs)} dataframes contained in a {type(dfs)}")
# turns out we do not get just one dataframe but a list of dataframes
# there could be 0 or more dataframes in the list
# Out:
# We got 6 dataframes contained in a <class 'list'>

# %%
len(dfs) # why list and why such length ?
# well ss.com was made in early 2000s when tables were used for everything
# Out:
# 6

# %%
# mdn on table tag
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element/table

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html
# pandas reads tables by default ALL tables on the page

# %%
df = dfs[4] # the 5th table on our page has our info
# df is the standard name for a dataframe in pandas, could use anything else
df.head()
# Out:
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2        Street  R.   m2  \
# 0  Piedāvājam iegādei jaunu 6 istabu dzīvokli div...       Kugu 15   6  240
# 1  Silts 2-istabu dzīvoklis 10 min no Rīgas centr...  Altonavas 17   2   29
# 2  Tikko izremontēts dzīvoklis. Dzīvoklī duša un ...   Altonavas 9   1   30
# 3  Piedāvājam iegādei plašu un gaišu 3-istabu dzī...       Kugu 15   3   91
# 4  Tiek pārdots pavisam jauns divistabu dzīvoklis...   Ranka d. 31   2   44
#
#   Floor         Series Price, m2      Price
# 0   6/7            New   3,774 €  905,750 €
# 1   1/2  Pre-war house     434 €   12,580 €
# 2   2/2  Pre-war house     733 €   22,000 €
# 3   2/7         Recon.   2,335 €  212,500 €
# 4   3/4         Recon.   2,950 €  129,800 €

# %%
# we can see what shape it is
print(f"Shape: {df.shape}")
# Out:
# Shape: (30, 10)

# %%
df
# Out:
#     Announcements \tdate  Announcements \tdate.1  \
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
# 5                    NaN                     NaN
# 6                    NaN                     NaN
# 7                    NaN                     NaN
# 8                    NaN                     NaN
# 9                    NaN                     NaN
# 10                   NaN                     NaN
# 11                   NaN                     NaN
# 12                   NaN                     NaN
# 13                   NaN                     NaN
# 14                   NaN                     NaN
# 15                   NaN                     NaN
# 16                   NaN                     NaN
# 17                   NaN                     NaN
# 18                   NaN                     NaN
# 19                   NaN                     NaN
# 20                   NaN                     NaN
# 21                   NaN                     NaN
# 22                   NaN                     NaN
# 23                   NaN                     NaN
# 24                   NaN                     NaN
# 25                   NaN                     NaN
# 26                   NaN                     NaN
# 27                   NaN                     NaN
# 28                   NaN                     NaN
# 29                   NaN                     NaN
#
#                                Announcements \tdate.2            Street  R.  \
# 0   Izīrē dzīvokli ar mājīgu un komfortablu iekārt...          Stabu 49   2
# 1   Tiek izīrēts lielisks 2 istabu dzīvoklis ar sk...        Merkela 17   2
# 2   Īpašnieks izīrē , tiko pēc remonta , ar sadzīv...         Deglava 9   1
# 3   Владелец сдает новую 2-уровневую квартиру (гос...      Brivibas 101   3
# 4   Доступна уже сегодня. Владелец сдает новую ква...    Lachplesha 121   2
# 5   Plašs trīsistabu dzīvoklis ar balkonu Vēstniec...       Vilandes 10   3
# 6   Izīrē 1 istabu dzīvokli jaunā mājā, centra tuv...    Sadovnikova 39   1
# 7   Ilgtermiņa īrei pieejams mājīgs divu istabu dz...          Sporta 7   2
# 8   Tiek izīrēts 2-istabu dzīvoklis J. Daliņa ielā...       J. Dalina 8   2
# 9   Īzīrē 1-istabu dzīvokli centra (34 kv. m. ) ar...        Tomsona 24   1
# 10  Tiek izīrēts gaumīgs, mēbelēts, divistabu dzīv...     Strelnieku 6a   2
# 11  Īrei tiek piedāvāts mājīgs, gaišs dzīvoklis Ce...     Gertrudes 106   2
# 12  Īstermiņā no 2st. tiek izīrēts saulains, mājīg...         Vagonu 22   1
# 13  Tiek izīrēts labs 3-istabu dzīvoklis, aprīkots...        Klijanu 16   3
# 14  Vienistabas dzīvoklis ar malkas apkuri pēc rem...            Zaku 3   1
# 15  Fasādes māja un ieeja ēkā no ielas. Dzīvoklis ...  Laboratorijas 11   1
# 16  Izīrē 2-istabas dzīvokli ilgtermiņa īrei. Dzīv...          Chaka 82   2
# 17  Izīrē uz dažādiem termiņiem. Izcils skats pār ...          Teatra 4   2
# 18  Комфортное размещение на короткий срок. Для те...         Merkela 6   2
# 19  Izīrē mājīgu, gaišu 3-istabu dzīvokli, studio ...         Chaka 136   3
# 20  Mēbelēts jauns dzīvoklis renovētā mājā klusajā...        Dzirnavu 6   4
# 21  Izīrē klusu 2-istabu dzīvokli pagalma mājā 4. ...          Chaka 83   2
# 22  Ilgtermiņā tiek piedavāts ērts dzīvoklis ar vi...          Avotu 11   2
# 23  Izīrē 2 istabu dzīvokli centrā Blakus parkam -...          Chaka 58   2
# 24  Izīrē 3 istabu studio tipa dzīvokli renovētā ē...          Avotu 23   3
# 25  Izīrē 3 istabu dzīvokli centrā. Gaišs, saulain...          Stabu 61   3
# 26  Īpašnieks izīrē maigu, gaišu, daļēji mēbelēto ...      Brivibas 121   2
# 27  Tiek iznomata 1 izoleta istaba 5-istabu dzīvok...     Lachplesha 17   2
# 28  Kapitālais remonts, plastikāta stikla pakešu l...          Avotu 66   1
# 29  Labs Piedavājums Par Labu Cenu Divistabas dzīv...          Avotu 61   2
#
#      m2  Floor      Series Price, m2         Price
# 0    50    4/5     Perewar       6 €    300 €/mon.
# 1    49    4/5     Perewar   11.22 €    550 €/mon.
# 2    26    1/6      Recon.   13.42 €    349 €/mon.
# 3    73    1/5     Perewar    6.85 €    500 €/mon.
# 4    43    2/6         New    8.95 €    385 €/mon.
# 5   106    4/5     Perewar       8 €    848 €/mon.
# 6    25    2/7      Recon.   10.80 €    270 €/mon.
# 7    50    1/4     Perewar    7.90 €    395 €/mon.
# 8    64  12/24         New   10.94 €    700 €/mon.
# 9    34    3/5   Spec. pr.    9.71 €    330 €/mon.
# 10   54    2/3      Recon.    9.26 €    500 €/mon.
# 11   55    4/5     Perewar    7.82 €    430 €/mon.
# 12   28    2/5      Recon.    1.07 €      30 €/day
# 13   71    3/9         New    8.45 €    600 €/mon.
# 14   23    2/3     Perewar    5.65 €    130 €/mon.
# 15   24    6/6     Perewar    9.17 €    220 €/mon.
# 16   45    2/6     Perewar    3.78 €    170 €/mon.
# 17   62    5/6         New   10.48 €    650 €/mon.
# 18   39    3/5     Perewar   0.897 €      35 €/day
# 19   60    3/6     Perewar    6.50 €    390 €/mon.
# 20   96    3/5      Recon.   15.63 €  1,500 €/mon.
# 21   54    4/7     Perewar    6.11 €    330 €/mon.
# 22   55    3/6     Perewar    6.36 €    350 €/mon.
# 23   43    4/6      Recon.    8.14 €    350 €/mon.
# 24   75    3/4      Recon.    9.33 €    700 €/mon.
# 25   75    2/5     Perewar    5.33 €    400 €/mon.
# 26   53    5/5     Perewar    4.34 €    230 €/mon.
# 27   15    1/4   Spec. pr.   12.67 €    190 €/mon.
# 28   25    5/5     Perewar    7.20 €    180 €/mon.
# 29   41    1/2  Stalin pr.    4.02 €    165 €/mon.

# %%
# you can export to json, csv, excel, sql, etc
# df.to_json("center.json")
df.to_json("agenskalns.json", index=False) # index=False means do not write row numbers

# %%
# save to csv
# df.to_csv("center.csv")
df.to_csv("agenskalns.csv", index=False)

# %%
# we can save to excel as well
# this assume you installed pandas with pip install pandas[xls] or pip install pandas[all]
# df.to_excel("center.xlsx")
df.to_excel("agenskalns.xlsx", index=False)

# %%
# so pandas read html is great for scraping tables and it is very easy to use
# restrictions are that it can only read tables and it can only read tables that are in the same format

# in our case we want to extract links to each flat
# so we will need to use beautiful soup or some other library

# %%
# url2 = "https://www.ss.com/lv/real-estate/flats/riga/centre/sell/page2.html"
url2 = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/page2.html"
print(f"URL: {url2}")
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/page2.html

# %%
dflist = pd.read_html(url2, header=0)
len(dflist)
# Out:
# 6

# %%
dflist[4].head() # getting start of 5th table from our 2nd html page
# Out:
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2          Street  R.  m2  \
# 0  Attīstītājs Pārdod plašu divu istabu dzīvokli ...   Kolkasraga 12   2  54
# 1  Remontējams trīsistabu dzīvoklis renovētā koka...    Lermontova 3   3  59
# 2  Gaišs ģimenes dzīvoklis gatavs dzīvošanai Dzīv...       Marupes 6   2  69
# 3  Pārdodās 1-istabas dzīvoklis. Malkas apkure, i...  M. Nometnu 11a   1  25
# 4  Dzīvoklis par vērtējuma cenu. Pārdodu saulainu...   Agenskalna 22   3  55
#
#   Floor         Series Price, m2      Price
# 0   1/3            New   2,694 €  145,500 €
# 1   1/2         Recon.   1,522 €   89,800 €
# 2   4/4         Recon.   2,203 €  152,000 €
# 3   2/3  Pre-war house     760 €   19,000 €
# 4   5/5       Chrusch.   1,345 €   74,000 €

# %%
df_from_page2 = dflist[4]
# check head
df_from_page2.head()
# Out:
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2          Street  R.  m2  \
# 0  Attīstītājs Pārdod plašu divu istabu dzīvokli ...   Kolkasraga 12   2  54
# 1  Remontējams trīsistabu dzīvoklis renovētā koka...    Lermontova 3   3  59
# 2  Gaišs ģimenes dzīvoklis gatavs dzīvošanai Dzīv...       Marupes 6   2  69
# 3  Pārdodās 1-istabas dzīvoklis. Malkas apkure, i...  M. Nometnu 11a   1  25
# 4  Dzīvoklis par vērtējuma cenu. Pārdodu saulainu...   Agenskalna 22   3  55
#
#   Floor         Series Price, m2      Price
# 0   1/3            New   2,694 €  145,500 €
# 1   1/2         Recon.   1,522 €   89,800 €
# 2   4/4         Recon.   2,203 €  152,000 €
# 3   2/3  Pre-war house     760 €   19,000 €
# 4   5/5       Chrusch.   1,345 €   74,000 €

# %%
# bigdf = pd.concat([df, dflist[4]]) # concat creates a new dataframe from an iterable! of dataframes
bigdf = pd.concat([df, df_from_page2]) # concat creates a new dataframe from an iterable! of dataframes
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
# print shape
print(f"Shape: {bigdf.shape}")
bigdf.head()
# Out:
# Shape: (60, 10)
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2        Street  R.   m2  \
# 0  Piedāvājam iegādei jaunu 6 istabu dzīvokli div...       Kugu 15   6  240
# 1  Silts 2-istabu dzīvoklis 10 min no Rīgas centr...  Altonavas 17   2   29
# 2  Tikko izremontēts dzīvoklis. Dzīvoklī duša un ...   Altonavas 9   1   30
# 3  Piedāvājam iegādei plašu un gaišu 3-istabu dzī...       Kugu 15   3   91
# 4  Tiek pārdots pavisam jauns divistabu dzīvoklis...   Ranka d. 31   2   44
#
#   Floor         Series Price, m2      Price
# 0   6/7            New   3,774 €  905,750 €
# 1   1/2  Pre-war house     434 €   12,580 €
# 2   2/2  Pre-war house     733 €   22,000 €
# 3   2/7         Recon.   2,335 €  212,500 €
# 4   3/4         Recon.   2,950 €  129,800 €

# %%
df.shape, dflist[4].shape, bigdf.shape
# so we see that we were successful in combining the two dataframes
# we can save the bigdf again to csv, json, sql, excel, etc
# Out:
# ((30, 10), (30, 10), (60, 10))

# %%
# so if we know the last page of our search we can loop through all pages
# however that can change from day to day
# better would be to use some automation to find the last page

# %%
# Challenge how to automatically get all pages no matter how many ads?
# how to scrape web address for each ad (in case we want to look in to the ad more in depth)

# for this we need to use beautiful soup to parse the html and extract the links needed
